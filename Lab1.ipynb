# %% [markdown]
# # Лабораторная работа 1
#
# ## Клепиков Никита
#
# Dataset: Students Performance in Exams
#
# Ссылка на датасет: https://www.kaggle.com/spscientist/students-performance-in-exams
#
# Группа: 6231 - 010402D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv('Students.csv')
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# * gender - пол (бинарный)
#         male - мужской
#         female - женский
# * race/ethnicity - раса/этническая принадлежность (категориальный)
#         group A
#         group B
#         group C
#         group D
#         group E
#
# * parental level of education - уровень образования родителей (категориальный)
#         bachelor's degree - степень бакалавра
#         some college - несколько колледжей
#         master's degree - степень магистра
#         associate's degree - степень младшего специалиста
#         high school - средняя школа
#         some high school - несколько средних школ
# * lunch - обед (бинарный)
#         standard - стандартный
#         free/reduced - бесплатный/льготный
# * test preparation course - курс подготовки к экзаменам (бинарный)
#         completed - пройден
#         none - не пройден
# * math score - баллы по математике (числовой)
#
# * reading score - баллы по чтению (числовой)
#
# * writing score - баллы по письменному экзамену (числовой)

# %% [markdown]
# ## Хорошая визуализация

# %%
sns.pairplot(students, hue='gender', palette='Set1')

# %%
students[["writing score", "parental level of education"]].groupby("parental level of education").sum().plot.bar(figsize=(15, 10))
plt.show()

# %%
plt.suptitle('dependence of scores in mathematics on the number of students')
plt.xlabel('math score')
plt.ylabel('number of students')
plt.hist(students["math score"],20)
plt.show()

# %% [markdown]
# ## Плохая визуализация

# %%
X = np.transpose([students['writing score'].values, students['math score'].values])
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
sns.boxplot(x = 'writing score', y = 'math score', data = students)
plt.show()

# %%
students[["race/ethnicity", "lunch"]].groupby("race/ethnicity").count().rename(columns={"lunch": "Count"}).plot.pie(subplots=True, figsize=(10, 10))
plt.show()
